# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\wania_96\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (0.3.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: setuptools in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (8.2.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: jinja2 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\wania_96\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\wania_96\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\wania_96\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\wania_96\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wania_96\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wania_96\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wania_96\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wania_96\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\wania_96\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\wania_96\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: colorama in c:\users\wania_96\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\wania_96\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\wania_96\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\wania_96\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)

# %%
# !pip install --upgrade spacy pydantic
# Out:
# Requirement already satisfied: spacy in c:\users\wania_96\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: pydantic in c:\users\wania_96\anaconda3\lib\site-packages (2.4.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (0.3.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: setuptools in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (8.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: jinja2 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\wania_96\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\wania_96\anaconda3\lib\site-packages (from pydantic) (2.10.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\wania_96\anaconda3\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\wania_96\anaconda3\lib\site-packages (from pydantic) (4.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\wania_96\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wania_96\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wania_96\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wania_96\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wania_96\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\wania_96\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\wania_96\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: colorama in c:\users\wania_96\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\wania_96\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\wania_96\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\wania_96\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)

# %%
import numpy as np 
import pandas as pd
import spacy
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
train=pd.read_csv(r'C:\Users\wania_96\Desktop\disaster-nlp\train.csv')
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
train.isnull().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
len(train)
# Out:
# 7613

# %%
train['target'].value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %%
#For simplicity, we will just be focusing on text and target column. We will drop the id, keyword and location columns.
train=train.drop(['id','keyword','location'],axis=1)
train.head()
# Out:
#                                                 text  target
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1

# %% [markdown]
# # Data Preprocessing

# %% [raw]
# We will create a few functions for doing some text preprocessing:
#
# Lowercase all the text
# Replace some abbreviations
# Remove stopwords (words such as 'and', 'the','is')
# Lemmatization (convert words to base form)
# Remove HTML tags
# Remove URL
# Remove special characters

# %%
#Text lowercasing
def lowercase(text):
    return text.lower()

# %%
replacements = {
    "he's": "he is",
    "she's": "she is",
    "it's": "it is",
    "I'm": "I am",
    "you're": "you are",
    "we're": "we are",
    "they're": "they are",
    "he'll": "he will",
    "she'll": "she will",
    "it'll": "it will",
    "i'll": "i will",
    "you'll": "you will",
    "we'll": "we will",
    "they'll": "they will",
    "he'd": "he would",
    "she'd": "she would",
    "it'd": "it would",
    "i'd": "i would",
    "you'd": "you would",
    "we'd": "we would",
    "they'd": "they would",
    "haven't": "have not",
    "hasn't": "has not",
    "hadn't": "had not",
    "don't": "do not",
    "doesn't": "does not",
    "didn't": "did not",
    "can't": "cannot",
    "won't": "will not",
    "wouldn't": "would not",
    "shouldn't": "should not",
    "mightn't": "might not",
    "mustn't": "must not",
    "aren't": "are not",
    "isn't": "is not",
    "wasn't": "was not",
    "weren't": "were not",
    # Add more replacements as needed
}

# %%
#Abberivation replacement
def replace_abb(text):
    # Define a dictionary of replacements for short form pronouns and contraction
    
    # Iterate through the replacements and apply them to the text
    for short_form, full_form in replacements.items():
        text = text.replace(short_form, full_form)
    
    return text

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def remove_stopwords(text):
    doc = nlp(text)
    filtered_text = ' '.join([token.lemma_ for token in doc if not token.is_stop])
    return filtered_text

# %%
#HTML tag removal
def remove_html_tags(input_text):
    soup = BeautifulSoup(input_text, 'html.parser')
    text_without_tags = soup.get_text()
    return text_without_tags

# %%
#URL data removal
def remove_url(data):
    url_clean= re.compile(r"https://\S+|www\.\S+")
    data=url_clean.sub(r'',data)
    return data

# %%
#Special Character removal
def remove_special_characters(text):
    # Define a regular expression pattern to match special characters
    pattern = r'[=!#%@$^&*()_+{}\[\]:;"\'<>,.?/|\\\-]|[0-9]'
    
    # Use the sub() function to replace matches with an empty string
    cleaned_text = re.sub(pattern, ' ', text)
    return cleaned_text

# %%
train['filtered_text']=train['text'].apply(lowercase)
train['filtered_text'] = train['filtered_text'].apply(replace_abb)
train['filtered_text'] = train['filtered_text'].apply(remove_stopwords)
train['filtered_text'] = train['filtered_text'].apply(remove_html_tags)
train['filtered_text'] = train['filtered_text'].apply(remove_url)
train['filtered_text'] = train['filtered_text'].apply(remove_special_characters)
# Out:
# C:\Users\wania_96\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
train.head()
# Out:
#                                                 text  target  \
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1
#
#                                        filtered_text
# 0             deed reason   earthquake allah forgive
# 1            forest fire near la ronge sask   canada
# 2  resident ask   shelter place   notify officer ...
# 3         people receive   wildfire evacuation or...
# 4  get send photo ruby   alaska smoke   wildfire ...

# %%
disaster_tweets = train[train['target'] == 1]['text']
non_disaster_tweets = train[train['target'] == 0]['text']

# %%
combined_text_pos = ' '.join(train[train['target']==1]['filtered_text'])
combined_text_neg = ' '.join(train[train['target']==0]['filtered_text'])

wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(combined_text_pos)
wordcloud_neg = WordCloud(width=800, height=400, background_color='white').generate(combined_text_neg)

# %%
#Actual disaster wordcloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %%
#False disaster wordcloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %% [markdown]
# We can see that there are a few common words that keep appearing in both wordcloud. We will remove the following:
#
# Common words: co, time, new, think, amp
# Individual letters a-z
# u with circumflex

# %%
#Remove common words
import re

def remove_special_characters(text):
    words_to_remove = ['co', 'time', 'new', 'think', 'amp']
    letters_to_remove = r'\b[a-z]\b'  # Matches individual letters from 'a' to 'z' as whole words
    u_circumflex = '\u00FB'  # u with circumflex
    
    # Remove specific words
    for word in words_to_remove:
        text = text.replace(word, '')

    # Remove individual letters from 'a' to 'z' if they are standalone words
    text = re.sub(letters_to_remove, '', text, flags=re.IGNORECASE)
    
    # Remove u with circumflex
    text = text.replace(u_circumflex, '')

    return text

train['filtered_text'] = train['filtered_text'].apply(remove_special_characters)

# %%
train.head()
# Out:
#                                                 text  target  \
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1
#
#                                        filtered_text
# 0             deed reason   earthquake allah forgive
# 1            forest fire near la ronge sask   canada
# 2  resident ask   shelter place   notify officer ...
# 3         people receive   wildfire evacuation or...
# 4  get send photo ruby   alaska smoke   wildfire ...

# %%
combined_text_pos_2 = ' '.join(train[train['target']==1]['filtered_text'])
wordcloud_pos_2 = WordCloud(width=800, height=400, background_color='white').generate(combined_text_pos_2)

# %%
#Actual disaster wordcloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_pos_2, interpolation='bilinear')
plt.axis('off')  # Remove axes
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, f1_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
#Straified data split, to ensure the imbalanced dataset is split into both training and test set.
xtrain,xtest,ytrain,ytest=train_test_split(train['filtered_text'], train['target'], stratify=train['target'], test_size=0.3, random_state=42)

# %%
#Create Document Term Matrix
vectorizer = CountVectorizer()
xtrain = vectorizer.fit_transform(xtrain)
xtest = vectorizer.transform(xtest)

# %%
#Prediction using logistic regression
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression().fit(xtrain, ytrain)

# Predict sentiment on the test set
predictions_lr = logreg.predict(xtest)

# Calculate evaluation metrics
print("Accuracy of Logistic Regression:", accuracy_score(ytest, predictions_lr))
# Out:
# Accuracy of Logistic Regression: 0.7946584938704028

# %%
#Prediction using random forest classifier
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42).fit(xtrain, ytrain)

# Predict sentiment on the test set
predictions_rf = rf.predict(xtest)

# Calculate evaluation metrics
print("Accuracy of Random Forest Classifier:", accuracy_score(ytest, predictions_rf))
# Out:
# Accuracy of Random Forest Classifier: 0.7990367775831874

# %%
#Feature Importance of random forest

feature_importances = rf.feature_importances_

# Get feature names
feature_names = vectorizer.get_feature_names_out()

indices = np.argsort(feature_importances)[::-1]

# Get feature names (assuming X is a pandas DataFrame or a NumPy array with feature names)

# Plot the top 20 features in descending order
top_features_count = 20
plt.figure(figsize=(10, 6))
plt.title("Top 20 Feature Importances")
plt.bar(range(top_features_count), feature_importances[indices[:top_features_count]], align="center")
plt.xticks(range(top_features_count), [feature_names[i] for i in indices[:top_features_count]], rotation=45)
plt.xlabel("Feature")
plt.ylabel("Feature Importance")
plt.tight_layout()
plt.show()

# %%
print(train.columns)
# Out:
# Index(['text', 'target', 'filtered_text'], dtype='object')

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\wania_96\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\wania_96\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\wania_96\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\wania_96\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\wania_96\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\wania_96\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\wania_96\anaconda3\lib\site-packages)

# %% [markdown]
# import nltk
#
# # Download the missing Punkt tokenizer model
# nltk.download('punkt')

# %%
# For word2vec
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.models import Sequential

# %%
# Tokenize and apply word2vec model
train['filtered_text_token'] = train['filtered_text'].apply(word_tokenize)
w2v_model = Word2Vec(sentences=train['filtered_text_token'], vector_size=50, window=1, min_count=5, sg=0, seed=42)

# %%
train.head()
# Out:
#                                                 text  target  \
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1
#
#                                        filtered_text  \
# 0             deed reason   earthquake allah forgive
# 1            forest fire near la ronge sask   canada
# 2  resident ask   shelter place   notify officer ...
# 3         people receive   wildfire evacuation or...
# 4  get send photo ruby   alaska smoke   wildfire ...
#
#                                  filtered_text_token
# 0         [deed, reason, earthquake, allah, forgive]
# 1      [forest, fire, near, la, ronge, sask, canada]
# 2  [resident, ask, shelter, place, notify, office...
# 3  [people, receive, wildfire, evacuation, order,...
# 4  [get, send, photo, ruby, alaska, smoke, wildfi...

# %%
xtrain,xtest,ytrain,ytest=train_test_split(train['filtered_text'], train['target'], stratify=train['target'], test_size=0.3, random_state=42)

# %%
# Determine our max length pad sequence
print('max length of filtered text:',max(train['filtered_text_token'].apply(len)))
# Out:
# max length of filtered text: 21

# %%
# Convert words to indices using the Word2Vec model vocabulary
word_vectors = w2v_model.wv
tokenizer = Tokenizer()
tokenizer.word_index = {word: idx for idx, word in enumerate(word_vectors.index_to_key)}

# Convert text to sequences of word indices
sequences_train = tokenizer.texts_to_sequences(xtrain)
sequences_test = tokenizer.texts_to_sequences(xtest)

# Pad sequences for consistent input shape
max_sequence_length = 21  # Adjust this based on your dataset and sequence lengths
xtrain = pad_sequences(sequences_train, maxlen=max_sequence_length, padding='post')
xtest = pad_sequences(sequences_test, maxlen=max_sequence_length, padding='post')

# Create an embedding matrix
embedding_matrix = np.zeros((len(tokenizer.word_index) + 1, w2v_model.vector_size))
for word, idx in tokenizer.word_index.items():
    if word in word_vectors:
        embedding_matrix[idx] = word_vectors[word]

# Build LSTM model with Word2Vec embeddings
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=w2v_model.vector_size,
                    weights=[embedding_matrix], input_length=max_sequence_length, trainable=False))
model.add(LSTM(units=128, dropout=0.2,return_sequences=True))
model.add(LSTM(units=128, dropout=0.2))
model.add(Dense(units=1, activation='sigmoid'))  # For binary classification; use softmax for multi-class

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(xtrain, ytrain, epochs=50, batch_size=64, validation_data=(xtest, ytest))

# Evaluate the model
loss, accuracy = model.evaluate(xtest, ytest)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/50
# 84/84 [==============================] - 7s 61ms/step - loss: 0.6858 - accuracy: 0.5682 - val_loss: 0.6859 - val_accuracy: 0.5705
# Epoch 2/50
# 84/84 [==============================] - 5s 55ms/step - loss: 0.6803 - accuracy: 0.5707 - val_loss: 0.6774 - val_accuracy: 0.5823
# Epoch 3/50
# 84/84 [==============================] - 5s 57ms/step - loss: 0.6613 - accuracy: 0.5997 - val_loss: 0.6563 - val_accuracy: 0.6068
# Epoch 4/50
# 84/84 [==============================] - 5s 57ms/step - loss: 0.6548 - accuracy: 0.6119 - val_loss: 0.6481 - val_accuracy: 0.6151
# Epoch 5/50
# 84/84 [==============================] - 5s 57ms/step - loss: 0.6496 - accuracy: 0.6170 - val_loss: 0.6491 - val_accuracy: 0.6230
# Epoch 6/50
# 84/84 [==============================] - 5s 60ms/step - loss: 0.6452 - accuracy: 0.6221 - val_loss: 0.6500 - val_accuracy: 0.6191
# Epoch 7/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6453 - accuracy: 0.6262 - val_loss: 0.6533 - val_accuracy: 0.6182
# Epoch 8/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6453 - accuracy: 0.6221 - val_loss: 0.6485 - val_accuracy: 0.6156
# Epoch 9/50
# 84/84 [==============================] - 6s 66ms/step - loss: 0.6479 - accuracy: 0.6176 - val_loss: 0.6544 - val_accuracy: 0.6099
# Epoch 10/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.6426 - accuracy: 0.6316 - val_loss: 0.6539 - val_accuracy: 0.6213
# Epoch 11/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.6451 - accuracy: 0.6313 - val_loss: 0.6611 - val_accuracy: 0.6064
# Epoch 12/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.6445 - accuracy: 0.6283 - val_loss: 0.6471 - val_accuracy: 0.6178
# Epoch 13/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.6431 - accuracy: 0.6243 - val_loss: 0.6453 - val_accuracy: 0.6274
# Epoch 14/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.6478 - accuracy: 0.6228 - val_loss: 0.6468 - val_accuracy: 0.6191
# Epoch 15/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.6412 - accuracy: 0.6365 - val_loss: 0.6441 - val_accuracy: 0.6235
# Epoch 16/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.6414 - accuracy: 0.6260 - val_loss: 0.6448 - val_accuracy: 0.6243
# Epoch 17/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.6407 - accuracy: 0.6311 - val_loss: 0.6425 - val_accuracy: 0.6230
# Epoch 18/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6391 - accuracy: 0.6313 - val_loss: 0.6463 - val_accuracy: 0.6208
# Epoch 19/50
# 84/84 [==============================] - 6s 70ms/step - loss: 0.6432 - accuracy: 0.6283 - val_loss: 0.6434 - val_accuracy: 0.6296
# Epoch 20/50
# 84/84 [==============================] - 6s 70ms/step - loss: 0.6399 - accuracy: 0.6352 - val_loss: 0.6457 - val_accuracy: 0.6217
# Epoch 21/50
# 84/84 [==============================] - 6s 70ms/step - loss: 0.6389 - accuracy: 0.6405 - val_loss: 0.6454 - val_accuracy: 0.6195
# Epoch 22/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6406 - accuracy: 0.6299 - val_loss: 0.6486 - val_accuracy: 0.6265
# Epoch 23/50
# 84/84 [==============================] - 6s 66ms/step - loss: 0.6378 - accuracy: 0.6378 - val_loss: 0.6410 - val_accuracy: 0.6261
# Epoch 24/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.6380 - accuracy: 0.6410 - val_loss: 0.6455 - val_accuracy: 0.6226
# Epoch 25/50
# 84/84 [==============================] - 6s 74ms/step - loss: 0.6375 - accuracy: 0.6373 - val_loss: 0.6379 - val_accuracy: 0.6353
# Epoch 26/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6360 - accuracy: 0.6391 - val_loss: 0.6523 - val_accuracy: 0.6239
# Epoch 27/50
# 84/84 [==============================] - 6s 68ms/step - loss: 0.6400 - accuracy: 0.6322 - val_loss: 0.6383 - val_accuracy: 0.6379
# Epoch 28/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6362 - accuracy: 0.6461 - val_loss: 0.6390 - val_accuracy: 0.6287
# Epoch 29/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.6339 - accuracy: 0.6393 - val_loss: 0.6378 - val_accuracy: 0.6432
# Epoch 30/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6379 - accuracy: 0.6391 - val_loss: 0.6359 - val_accuracy: 0.6362
# Epoch 31/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6352 - accuracy: 0.6418 - val_loss: 0.6390 - val_accuracy: 0.6375
# Epoch 32/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.6345 - accuracy: 0.6433 - val_loss: 0.6362 - val_accuracy: 0.6349
# Epoch 33/50
# 84/84 [==============================] - 6s 68ms/step - loss: 0.6346 - accuracy: 0.6467 - val_loss: 0.6409 - val_accuracy: 0.6375
# Epoch 34/50
# 84/84 [==============================] - 6s 73ms/step - loss: 0.6329 - accuracy: 0.6412 - val_loss: 0.6372 - val_accuracy: 0.6344
# Epoch 35/50
# 84/84 [==============================] - 6s 77ms/step - loss: 0.6342 - accuracy: 0.6391 - val_loss: 0.6353 - val_accuracy: 0.6436
# Epoch 36/50
# 84/84 [==============================] - 6s 70ms/step - loss: 0.6350 - accuracy: 0.6393 - val_loss: 0.6343 - val_accuracy: 0.6462
# Epoch 37/50
# 84/84 [==============================] - 6s 70ms/step - loss: 0.6346 - accuracy: 0.6429 - val_loss: 0.6394 - val_accuracy: 0.6366
# Epoch 38/50
# 84/84 [==============================] - 6s 72ms/step - loss: 0.6330 - accuracy: 0.6421 - val_loss: 0.6427 - val_accuracy: 0.6278
# Epoch 39/50
# 84/84 [==============================] - 6s 75ms/step - loss: 0.6332 - accuracy: 0.6425 - val_loss: 0.6334 - val_accuracy: 0.6445
# Epoch 40/50
# 84/84 [==============================] - 6s 74ms/step - loss: 0.6330 - accuracy: 0.6380 - val_loss: 0.6355 - val_accuracy: 0.6318
# Epoch 41/50
# 84/84 [==============================] - 6s 72ms/step - loss: 0.6341 - accuracy: 0.6470 - val_loss: 0.6336 - val_accuracy: 0.6458
# Epoch 42/50
# 84/84 [==============================] - 6s 71ms/step - loss: 0.6340 - accuracy: 0.6431 - val_loss: 0.6345 - val_accuracy: 0.6401
# Epoch 43/50
# 84/84 [==============================] - 6s 70ms/step - loss: 0.6303 - accuracy: 0.6438 - val_loss: 0.6337 - val_accuracy: 0.6397
# Epoch 44/50
# 84/84 [==============================] - 6s 71ms/step - loss: 0.6315 - accuracy: 0.6491 - val_loss: 0.6326 - val_accuracy: 0.6414
# Epoch 45/50
# 84/84 [==============================] - 7s 78ms/step - loss: 0.6325 - accuracy: 0.6399 - val_loss: 0.6394 - val_accuracy: 0.6445
# Epoch 46/50
# 84/84 [==============================] - 6s 71ms/step - loss: 0.6301 - accuracy: 0.6476 - val_loss: 0.6328 - val_accuracy: 0.6471
# Epoch 47/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.6289 - accuracy: 0.6483 - val_loss: 0.6312 - val_accuracy: 0.6449
# Epoch 48/50
# 84/84 [==============================] - 6s 68ms/step - loss: 0.6283 - accuracy: 0.6500 - val_loss: 0.6330 - val_accuracy: 0.6384
# Epoch 49/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.6265 - accuracy: 0.6502 - val_loss: 0.6385 - val_accuracy: 0.6384
# Epoch 50/50
# 84/84 [==============================] - 6s 70ms/step - loss: 0.6316 - accuracy: 0.6455 - val_loss: 0.6327 - val_accuracy: 0.6419
# 72/72 [==============================] - 1s 10ms/step - loss: 0.6327 - accuracy: 0.6419
# Accuracy: 64.19%

# %%
test=pd.read_csv(r'C:\Users\wania_96\Desktop\disaster-nlp\test.csv')
test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
Id=test['id']
test=test.drop(['id','keyword','location'],axis=1)

# %%
test['filtered_text'] = test['text'].apply(lowercase)
test['filtered_text'] = test['filtered_text'].apply(replace_abb)
test['filtered_text'] = test['filtered_text'].apply(remove_stopwords)
test['filtered_text'] = test['filtered_text'].apply(remove_html_tags)
test['filtered_text'] = test['filtered_text'].apply(remove_url)
test['filtered_text'] = test['filtered_text'].apply(remove_special_characters)
test['filtered_text'] = test['filtered_text'].apply(remove_special_characters)

test = vectorizer.transform(test['filtered_text'])
# Out:
# C:\Users\wania_96\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
ypred=rf.predict(test)
final = np.round(ypred)
output = pd.DataFrame({'id': Id,'target': final.astype(int) })
output
# Out:
#          id  target
# 0         0       0
# 1         2       1
# 2         3       1
# 3         9       1
# 4        11       1
# ...     ...     ...
# 3258  10861       1
# 3259  10865       1
# 3260  10868       1
# 3261  10874       1
# 3262  10875       0
#
# [3263 rows x 2 columns]

# %%
output.to_csv('submission.csv', index=False)
